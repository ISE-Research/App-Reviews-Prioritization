# %%
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import metrics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/merged_data_ready_to_train with intention without feature name.csv'
data = pd.read_csv(path)

# %%
data
# Out:
#         f0  f1      f2   f3        f4  ...  f26  f27  f28  f29  output
# 0        1  25   75.88  3.7  1.000000  ...    0    0    0    1       2
# 1        5  63   77.23  5.2  0.575000  ...    0    0    1    0       1
# 2        1   2  121.22 -3.5  0.500000  ...    0    0    0    1       1
# 3        5   4  121.22 -3.5  0.600000  ...    0    0    0    1       3
# 4        1   9  120.21 -3.1  0.900000  ...    0    0    0    1       0
# ...     ..  ..     ...  ...       ...  ...  ...  ...  ...  ...     ...
# 308376   2   4  121.22 -3.5  0.600000  ...    0    0    0    1       0
# 308377   1   6   36.62  8.4  0.000000  ...    0    0    0    1       1
# 308378   3  34   73.85  4.5  0.916667  ...    0    0    0    1       0
# 308379   2   4  121.22 -3.5  0.000000  ...    0    0    0    1       0
# 308380   4  12  119.19 -2.7  1.000000  ...    0    0    0    1       3
#
# [308381 rows x 31 columns]

# %%
data=data.drop(['f8', 'f9','f10','f11','f13','f15','f16','f17','f18','f19','f20','f22','f23','f24','f25','f26','f27','f28'], axis = 1)

# %%
# Get names of indexes for which column Age has value 30
indexNames = data[ data['output'] == -1].index
# print(indexNames)
# Delete these row indexes from dataFrame
data.drop(indexNames , inplace=True)
data
# Out:
#         f0  f1      f2   f3        f4  ...  f26  f27  f28  f29  output
# 0        1  25   75.88  3.7  1.000000  ...    0    0    0    1       2
# 1        5  63   77.23  5.2  0.575000  ...    0    0    1    0       1
# 2        1   2  121.22 -3.5  0.500000  ...    0    0    0    1       1
# 3        5   4  121.22 -3.5  0.600000  ...    0    0    0    1       3
# 4        1   9  120.21 -3.1  0.900000  ...    0    0    0    1       0
# ...     ..  ..     ...  ...       ...  ...  ...  ...  ...  ...     ...
# 308376   2   4  121.22 -3.5  0.600000  ...    0    0    0    1       0
# 308377   1   6   36.62  8.4  0.000000  ...    0    0    0    1       1
# 308378   3  34   73.85  4.5  0.916667  ...    0    0    0    1       0
# 308379   2   4  121.22 -3.5  0.000000  ...    0    0    0    1       0
# 308380   4  12  119.19 -2.7  1.000000  ...    0    0    0    1       3
#
# [284062 rows x 29 columns]

# %%
# data.loc[(data["output"] ==0)] = 1
data.loc[data.output==0, 'output'] = 1

# %%
# data.loc[(data["output"] ==2)] = 1
data.loc[data.output==2, 'output'] = 1

# %%
# data.loc[(data["output"] ==3)] = 1
data.loc[data.output==3, 'output'] = 1

# %%
# data.loc[(data["output"] >3)] = 0
data.loc[data.output>3, 'output'] = 0
data
# Out:
#         f0  f1      f2   f3        f4  ...  f26  f27  f28  f29  output
# 0        1  25   75.88  3.7  1.000000  ...    0    0    0    1       1
# 1        5  63   77.23  5.2  0.575000  ...    0    0    1    0       1
# 2        1   2  121.22 -3.5  0.500000  ...    0    0    0    1       1
# 3        5   4  121.22 -3.5  0.600000  ...    0    0    0    1       1
# 4        1   9  120.21 -3.1  0.900000  ...    0    0    0    1       1
# ...     ..  ..     ...  ...       ...  ...  ...  ...  ...  ...     ...
# 308376   2   4  121.22 -3.5  0.600000  ...    0    0    0    1       1
# 308377   1   6   36.62  8.4  0.000000  ...    0    0    0    1       1
# 308378   3  34   73.85  4.5  0.916667  ...    0    0    0    1       1
# 308379   2   4  121.22 -3.5  0.000000  ...    0    0    0    1       1
# 308380   4  12  119.19 -2.7  1.000000  ...    0    0    0    1       1
#
# [284062 rows x 29 columns]

# %%
X = data.drop('output', axis=1)
y = data['output']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
DecisionTreeClassifier_model = tree.DecisionTreeClassifier()
DecisionTreeClassifier_model = DecisionTreeClassifier_model.fit(X_train, y_train)

# %%
y_pred_DecisionTreeClassifier_model= DecisionTreeClassifier_model.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_DecisionTreeClassifier_model))
# Out:
# Accuracy: 0.8579550455001496

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_DecisionTreeClassifier_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.14      0.13      0.14      4912
#            1       0.92      0.93      0.92     51901
#
#     accuracy                           0.86     56813
#    macro avg       0.53      0.53      0.53     56813
# weighted avg       0.85      0.86      0.85     56813
