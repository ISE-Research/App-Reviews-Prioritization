# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
#librabires for plot
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import LinearSVC
import io

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# path = '/content/drive/My Drive/ready_to_train.csv'
# data1 = pd.read_csv(path)
# data=data1.drop(['reviews','review_date'], axis=1)

# %%
# path = '/content/drive/My Drive/ready_to_train_0 to120000 reviews.csv'
# path = '/content/drive/My Drive/thesis-part1-combined 76402 reviews_ready_to_train with tf-idf and adv and adj.csv'
path = '/content/drive/My Drive/thesis-part1-combined 76402 reviews_ready_to_train with tf-idf and adv and adj and intention.csv'

data0 = pd.read_csv(path)
# data=data1.drop(data1.columns[[0,1, 2,4]], axis = 1, inplace = True) 
# data=data1.drop(['reviews','date'], axis=1)
# data.drop(data.columns[[0,1,4]], axis = 1, inplace = True)

# %%
data = data0.reindex(np.random.permutation(data0.index))

# %%
data
# Out:
#        helpfulness  rate  ... information giving  other
# 59992            0     4  ...                  0      0
# 59782            6     4  ...                  0      1
# 2521             0     5  ...                  0      1
# 66183            2     1  ...                  1      0
# 33852            7     5  ...                  0      1
# ...            ...   ...  ...                ...    ...
# 11245            0     5  ...                  0      1
# 14641            0     1  ...                  0      1
# 17140            3     5  ...                  1      0
# 39981            0     4  ...                  0      1
# 67463            0     1  ...                  0      1
#
# [76401 rows x 37 columns]

# %%
data=data.drop(data.columns[2], axis=1)

# %%
data=data.drop(data.columns[6], axis=1)

# %%
data
# Out:
#        helpfulness  rate  ...  information giving  other
# 59992            0     4  ...                   0      0
# 59782            6     4  ...                   0      1
# 2521             0     5  ...                   0      1
# 66183            2     1  ...                   1      0
# 33852            7     5  ...                   0      1
# ...            ...   ...  ...                 ...    ...
# 11245            0     5  ...                   0      1
# 14641            0     1  ...                   0      1
# 17140            3     5  ...                   1      0
# 39981            0     4  ...                   0      1
# 67463            0     1  ...                   0      1
#
# [76401 rows x 35 columns]

# %%
X = data.drop('response', axis=1)
y = data['response']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %% [markdown]
# # implementing Simple SVM

# %%
# svclassifier_linear = SVC(kernel='linear')
# svclassifier_linear.fit(X_train, y_train)

# %%
# y_pred_svclassifier_linear = svclassifier_linear.predict(X_test)

# %%
# print(confusion_matrix(y_test,y_pred_svclassifier_linear))
# print(classification_report(y_test,y_pred_svclassifier_linear))

# %% [markdown]
# #implementing Kernel SVM

# %%
# svclassifier_poly = SVC(kernel='poly', degree=1)
# svclassifier_poly.fit(X_train, y_train)

# %%
# y_pred_svclassifier_poly = svclassifier_poly.predict(X_test)

# %%
# print(confusion_matrix(y_test, y_pred_svclassifier_poly))
# print(classification_report(y_test, y_pred_svclassifier_poly))

# %%
# from sklearn.inspection import plot_partial_dependence
# features = [3,5,6]
# plot_partial_dependence(svclassifier_poly,X_train, features)

# %% [markdown]
# #implementing  Gaussian Kernel

# %%
svclassifier_rbf = SVC(kernel='rbf')
svclassifier_rbf.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred_svclassifier_rbf = svclassifier_rbf.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred_svclassifier_rbf))
print(classification_report(y_test, y_pred_svclassifier_rbf))
# Out:
# [[7191 2342]
#  [1578 4170]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.75      0.79      9533
#            1       0.64      0.73      0.68      5748
#
#     accuracy                           0.74     15281
#    macro avg       0.73      0.74      0.73     15281
# weighted avg       0.75      0.74      0.75     15281

# %%
from sklearn.inspection import plot_partial_dependence
features = [3,5,6]
plot_partial_dependence(svclassifier_rbf,X_train, features)

# %% [markdown]
# #implementing Sigmoid Kernel

# %%
svclassifier_sigmoid = SVC(kernel='sigmoid')
svclassifier_sigmoid.fit(X_train, y_train)

# %%
y_pred_svclassifier_sigmoid = svclassifier_sigmoid.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred_svclassifier_sigmoid))
print(classification_report(y_test, y_pred_svclassifier_sigmoid))
